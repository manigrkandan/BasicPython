# %%
print('HOPE AI')
# Out:
# HOPE AI

# %%
Institute_Input = input('Enter your institute name? : ')
# Out:
# Enter your institute name? : HOPE AI

# %%
NameInput = input('Enter your name: ')
AgeInput = input('Enter your age: ')
SchoolInput = input('Enter your school name: ')
StudyInput = input('Enter your degree: ')
# Out:
# Enter your name: Mani
# Enter your age: 32
# Enter your school name: Prince
# Enter your degree: PGDM SCM

# %%
a = 43
b = 34
add = a + b
print(f"a = {a}")
print(f"b= {b}")
print(f"add = {add}")
# Out:
# a = 43
# b= 34
# add = 77

# %%
a = 43
b = 34
sub = a - b
print(f"a = {a}")
print(f"b= {b}")
print(f"sub = {sub}")
# Out:
# a = 43
# b= 34
# sub = 9

# %%
a = 63
b = 97
mul = a * b
print(f"a = {a}")
print(f"b= {b}")
print(f"Mul = {mul}")
# Out:
# a = 63
# b= 97
# Mul = 6111

# %%
a = 76
b = 31
div = a / b
print(f"a = {a}")
print(f"b= {b}")
print(f"Float Div = {div}")
# Out:
# a = 76
# b= 31
# Float Div = 2.4516129032258065

# %%
a = 76
b = 31
floor = a // b
print(f"a = {a}")
print(f"b= {b}")
print(f"Floor Div = {floor}")
# Out:
# a = 76
# b= 31
# Floor Div = 2

# %%
a = 76
b = 31
mod = a % b
print(f"a = {a}")
print(f"b= {b}")
print(f"Modulo = {mod}")
# Out:
# a = 76
# b= 31
# Modulo = 14

# %%
a = 4
b = 4
power = a ** b
print(f"a = {a}")
print(f"b= {b}")
print(f"Power = {power}")
# Out:
# a = 4
# b= 4
# Power = 256
