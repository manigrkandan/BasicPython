# %%
#1.What is wrong with the following function definition, and how do you fix it?
#Correction - Function definition misses : at the end of the definition. name parameter is empty. Either it has to be assigned or value to be passed. 

def say_hello(name):
    name = "Text"
    print("Hello, " + name)

# %%
#2.What error will occur in the following code, and how do you fix it?
#Correction - You cannot concatenate int and str together in a single statement. f Strings can be used instead

age = 25
print(f"I am {age} years old")
# Out:
# I am 25 years old

# %%
#3.Question:
#What is the issue with the following code?
#Correction - Message is declared inside the greet function and hence it cannot be directly referred.
def greet():
    message = "Hello"
    return message
print(greet())
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?
#Correction - add function has 2 parameters, but only 1 is passed instead. Need to pass one more parameter for the function to be called. 
def add(a, b):
    return a + b

print(add(5,4))
# Out:
# 9

# %%
#5.What is wrong with this code?
#Correction - Logic issue. n%2 == 1 indicates odd. 
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False

# %%
#6.What happens when you run this code?
#Correction - str cannot be converted into a number unless a numerical value entered as a string. 
num = int("10")
print(num)
# Out:
# 10

# %%
#7.What will happen when you run the following code?
#Correction - Sort function sorts the list but do not store the list value and this will result in None parameter

numbers = [1, 2, 3, 4]
numbers.sort()
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?
#Correction - Similar to above, storing the value makes it none. We can straight away append the number to the list

numbers = [1, 2, 3]
numbers.append(4)
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?
#Correction - This will result in an infinte loop. There has to be a limiter or a condition that stops the loop. 

count = 10

def increment(count):
    while count <16:
        count += 1
        print(count)

increment(count)
# Out:
# 11
# 12
# 13
# 14
# 15
# 16

# %%
#10.What error will occur in the following code?
#Correction - Out of bounds. as the entire string length is 6. 
text = "Python"
print(text[5])
# Out:
# n
