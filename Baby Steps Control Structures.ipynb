# %%
print('Welcome to Assignment-1')
# Out:
# Welcome to Assignment-1

# %%
Num1 = 10
Num2 = 30
Add = Num1 + Num2
print('Num1 = 10')
print('Num2 = 10')
print(f"Add = {Add}")
# Out:
# Num1 = 10
# Num2 = 10
# Add = 40

# %%
_BMI = float(input('Enter the BMI Index:'))
if(_BMI < 18.5):
    print('Underweight')
elif(_BMI <= 24.9):
    print('Normal Weight')
elif(_BMI <= 29.9):
    print('Overweight')
else:
    print('Obese')
# Out:
# Enter the BMI Index:34
# Obese
