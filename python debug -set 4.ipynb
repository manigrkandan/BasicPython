# %%
#1.Identify and fix the syntax error in the following code:
#Correction - syntax mistake in if statement

age = 18
if age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
#What error will occur in the following code?
#Correction - function name is greet(), but greet_user is called. function call has to be proper. 

def greet():
    print("Hello, World!")

greet()
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:
#Correction - Usage of f strings to solve the dynamic assignment of variables in print statement
name = "Alice"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question:
What will happen when you run this code?
#Correction - Math error, as division by zero exception. We cannot divide a number by zero
a = 10
b = 0
result = a / b
print(result)
# Out:
# Object `code` not found.
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 a = 10
#       5 b = 0
# ----> 6 result = a / b
#       7 print(result)
#
# ZeroDivisionError: division by zero

# %%
#5.What error will occur in the following code?
#Correction - Cannot convert a pure string into a number. If the num value has an integer in string format, this will work
num = int("123")
print(num)
# Out:
# 123

# %%
#6.Identify the issue in this code:
#Correction - Dictionary in python, uses key value pairs. we are trying to call a key which is not defined in data dictionary
data = {"name": "John", "age": 30, "city": "Chennai"}
print(data["city"])
# Out:
# Chennai

# %%
#7.What will happen when you run this code?
#Correction - Infinite loop issue. we have given a condition, which satisfies as true throughout the cycle. There should be some control on the loop.
num = 1
while num < 5:
    print(num)
    num += 1
# Out:
# 1
# 2
# 3
# 4

# %%
#8.What is wrong with this code?
#Correction - Out of bounds issue. we have only 3 values but calling the 4th element
fruits = ("apple", "banana", "cherry", "strawberry")
print(fruits[3])
# Out:
# strawberry

# %%
#9.What will happen when you run this code?
#correction - append is possible only on lists. string doesnt have append, we can concatenate. 
text = "hello world"
text = text + "!"
print(text)
# Out:
# hello world!

# %%
#10.What is wrong with the following code?
#Correction - there is no module called randoms. Its random. 
import random 
print(random.randint(0,10))
# Out:
# 1
