# %%
#1.Find the error in the following Python code:
#Correction - math has to be small case
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
#Correction - x has to be passed as a parameter to make it work
def my_function(x):
    x += 5
    print(x)

x = 10
my_function(x)
# Out:
# 15

# %%
#3.x = 5
#Correction - == to be used
if x == 10:
    print("x is 10")
# Out:
# x is 10

# %%
#4.
#Correction - works only if we do it separately
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.#Correction - number to be returned
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
#6.#Correction - Tuple is immutable. Cannot be changed
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
#7.#Correction - f strings can be used. 
name = "Alice"
age = 25
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Alice and I am 25 years old

# %%
#8.#Correction - to use ==. is checks for address value

a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.#Correction - Does not work, as for increment by default. Either it has to be 1,5 or to be decremented by -1
for i in range(5, 1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.#correction to be referenced as it is, instead of student[name], 
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
